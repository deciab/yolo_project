# %%
import os
from glob import glob
import pandas as pd
from functools import reduce
from xml.etree import ElementTree as et

# %%
xml_list = glob('./data_images/*.xml')
xmlfiles = list(map(lambda x : x.replace ('\\', '/'), xml_list))

# %%
xmlfiles
# Out:
# ['./data_images/cat001.xml',
#  './data_images/cat002.xml',
#  './data_images/cat003.xml',
#  './data_images/cat004.xml',
#  './data_images/cat005.xml',
#  './data_images/cat006.xml',
#  './data_images/cat007.xml',
#  './data_images/cat008.xml',
#  './data_images/cat009.xml',
#  './data_images/cat010.xml',
#  './data_images/cat011.xml',
#  './data_images/cat012.xml',
#  './data_images/cat013.xml',
#  './data_images/cat014.xml',
#  './data_images/cat015.xml',
#  './data_images/cat016.xml',
#  './data_images/cat017.xml',
#  './data_images/cat018.xml',
#  './data_images/cat019.xml',
#  './data_images/cat020.xml',
#  './data_images/cat021.xml',
#  './data_images/cat022.xml',
#  './data_images/cat023.xml',
#  './data_images/cat024.xml',
#  './data_images/cat025.xml',
#  './data_images/cat026.xml',
#  './data_images/cat027.xml',
#  './data_images/cat028.xml',
#  './data_images/cat029.xml',
#  './data_images/cat030.xml',
#  './data_images/cat031.xml',
#  './data_images/cat032.xml',
#  './data_images/cat033.xml',
#  './data_images/cat034.xml',
#  './data_images/cat035.xml',
#  './data_images/cat036.xml',
#  './data_images/cat037.xml',
#  './data_images/cat038.xml',
#  './data_images/cat039.xml',
#  './data_images/cat040.xml',
#  './data_images/cat041.xml',
#  './data_images/cat042.xml',
#  './data_images/cat043.xml',
#  './data_images/cat044.xml',
#  './data_images/cat045.xml',
#  './data_images/cat046.xml',
#  './data_images/cat047.xml',
#  './data_images/cat048.xml',
#  './data_images/cat049.xml',
#  './data_images/cat050.xml',
#  './data_images/cat051.xml',
#  './data_images/cat052.xml',
#  './data_images/cat053.xml',
#  './data_images/cat054.xml',
#  './data_images/cat055.xml',
#  './data_images/cat056.xml',
#  './data_images/cat057.xml',
#  './data_images/cat058.xml',
#  './data_images/cat059.xml',
#  './data_images/cat060.xml',
#  './data_images/cat061.xml',
#  './data_images/cat062.xml',
#  './data_images/cat063.xml',
#  './data_images/cat064.xml',
#  './data_images/cat065.xml',
#  './data_images/cat066.xml',
#  './data_images/cat067.xml',
#  './data_images/cat068.xml',
#  './data_images/cat069.xml',
#  './data_images/cat070.xml',
#  './data_images/cat071.xml',
#  './data_images/cat072.xml',
#  './data_images/cat073.xml',
#  './data_images/cat074.xml',
#  './data_images/cat075.xml',
#  './data_images/cat076.xml',
#  './data_images/cat077.xml',
#  './data_images/cat078.xml',
#  './data_images/cat079.xml',
#  './data_images/cat080.xml',
#  './data_images/cat081.xml',
#  './data_images/cat082.xml',
#  './data_images/cat083.xml',
#  './data_images/cat084.xml',
#  './data_images/cat085.xml',
#  './data_images/cat086.xml',
#  './data_images/cat087.xml',
#  './data_images/cat088.xml',
#  './data_images/cat089.xml',
#  './data_images/cat090.xml',
#  './data_images/cat091.xml',
#  './data_images/cat092.xml',
#  './data_images/cat093.xml',
#  './data_images/cat094.xml',
#  './data_images/cat095.xml',
#  './data_images/cat096.xml',
#  './data_images/cat097.xml',
#  './data_images/cat098.xml',
#  './data_images/cat099.xml',
#  './data_images/cat100.xml',
#  './data_images/dog001.xml',
#  './data_images/dog002.xml',
#  './data_images/dog003.xml',
#  './data_images/dog004.xml',
#  './data_images/dog005.xml',
#  './data_images/dog006.xml',
#  './data_images/dog007.xml',
#  './data_images/dog008.xml',
#  './data_images/dog009.xml',
#  './data_images/dog010.xml',
#  './data_images/dog011.xml',
#  './data_images/dog012.xml',
#  './data_images/dog013.xml',
#  './data_images/dog014.xml',
#  './data_images/dog015.xml',
#  './data_images/dog016.xml',
#  './data_images/dog017.xml',
#  './data_images/dog018.xml',
#  './data_images/dog019.xml',
#  './data_images/dog020.xml',
#  './data_images/dog021.xml',
#  './data_images/dog022.xml',
#  './data_images/dog023.xml',
#  './data_images/dog024.xml',
#  './data_images/dog025.xml',
#  './data_images/dog026.xml',
#  './data_images/dog027.xml',
#  './data_images/dog028.xml',
#  './data_images/dog029.xml',
#  './data_images/dog030.xml',
#  './data_images/dog031.xml',
#  './data_images/dog032.xml',
#  './data_images/dog033.xml',
#  './data_images/dog034.xml',
#  './data_images/dog035.xml',
#  './data_images/dog036.xml',
#  './data_images/dog037.xml',
#  './data_images/dog038.xml',
#  './data_images/dog039.xml',
#  './data_images/dog040.xml',
#  './data_images/dog041.xml',
#  './data_images/dog042.xml',
#  './data_images/dog043.xml',
#  './data_images/dog044.xml',
#  './data_images/dog045.xml',
#  './data_images/dog046.xml',
#  './data_images/dog047.xml',
#  './data_images/dog048.xml',
#  './data_images/dog049.xml',
#  './data_images/dog050.xml',
#  './data_images/dog051.xml',
#  './data_images/dog052.xml',
#  './data_images/dog053.xml',
#  './data_images/dog054.xml',
#  './data_images/dog055.xml',
#  './data_images/dog056.xml',
#  './data_images/dog057.xml',
#  './data_images/dog058.xml',
#  './data_images/dog059.xml',
#  './data_images/dog060.xml',
#  './data_images/dog061.xml',
#  './data_images/dog062.xml',
#  './data_images/dog063.xml',
#  './data_images/dog064.xml',
#  './data_images/dog065.xml',
#  './data_images/dog066.xml',
#  './data_images/dog067.xml',
#  './data_images/dog068.xml',
#  './data_images/dog069.xml',
#  './data_images/dog070.xml',
#  './data_images/dog071.xml',
#  './data_images/dog072.xml',
#  './data_images/dog073.xml',
#  './data_images/dog074.xml',
#  './data_images/dog075.xml',
#  './data_images/dog076.xml',
#  './data_images/dog077.xml',
#  './data_images/dog078.xml',
#  './data_images/dog079.xml',
#  './data_images/dog080.xml',
#  './data_images/dog081.xml',
#  './data_images/dog082.xml',
#  './data_images/dog083.xml',
#  './data_images/dog084.xml',
#  './data_images/dog085.xml',
#  './data_images/dog086.xml',
#  './data_images/dog087.xml',
#  './data_images/dog088.xml',
#  './data_images/dog089.xml',
#  './data_images/dog090.xml',
#  './data_images/dog091.xml',
#  './data_images/dog092.xml',
#  './data_images/dog093.xml',
#  './data_images/dog094.xml',
#  './data_images/dog095.xml',
#  './data_images/dog096.xml',
#  './data_images/dog097.xml',
#  './data_images/dog098.xml',
#  './data_images/dog099.xml',
#  './data_images/dog100.xml']

# %%
def extract_text(filename):   
    tree = et.parse(filename)
    root = tree.getroot()
    

    image_name = root.find('filename').text
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    objs = root.findall('object')
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append ([image_name, width, height, name, xmin, xmax, ymin, ymax])
    
    return parser

# %%
parser_all = list(map(extract_text, xmlfiles))

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
data
# Out:
# [['cat001.jpg', '1000', '688', 'cat', '124', '834', '156', '685'],
#  ['cat002.jpg', '1400', '700', 'cat', '390', '1219', '48', '697'],
#  ['cat003.jpg', '1080', '1080', 'cat', '140', '685', '1', '1072'],
#  ['cat004.jpg', '530', '640', 'cat', '64', '470', '57', '640'],
#  ['cat004.jpg', '530', '640', 'cat', '64', '469', '58', '639'],
#  ['cat005.jpg', '210', '210', 'cat', '13', '188', '8', '198'],
#  ['cat006.jpg', '1400', '845', 'cat', '422', '1259', '13', '840'],
#  ['cat007.jpg', '1795', '2397', 'cat', '398', '1608', '266', '2216'],
#  ['cat008.jpg', '2938', '4504', 'cat', '883', '2593', '784', '4138'],
#  ['cat009.jpg', '700', '467', 'cat', '207', '562', '33', '381'],
#  ['cat010.jpg', '1471', '980', 'cat', '44', '1428', '143', '797'],
#  ['cat011.jpg', '6000', '4000', 'cat', '354', '4754', '262', '3975'],
#  ['cat012.jpeg', '194', '260', 'cat', '45', '183', '27', '239'],
#  ['cat013.jpeg', '183', '276', 'cat', '36', '181', '41', '269'],
#  ['cat014.jpeg', '225', '225', 'cat', '23', '225', '22', '213'],
#  ['cat015.jpeg', '275', '183', 'cat', '25', '274', '12', '178'],
#  ['cat016.jpeg', '183', '275', 'cat', '2', '147', '41', '244'],
#  ['cat017.jpeg', '276', '183', 'cat', '72', '261', '36', '179'],
#  ['cat018.jpeg', '275', '183', 'cat', '93', '181', '10', '175'],
#  ['cat019.jpeg', '275', '183', 'cat', '22', '226', '35', '168'],
#  ['cat020.jpeg', '183', '275', 'cat', '28', '147', '76', '245'],
#  ['cat021.jpeg', '183', '275', 'cat', '1', '150', '32', '235'],
#  ['cat022.jpeg', '300', '168', 'cat', '73', '249', '7', '162'],
#  ['cat023.jpeg', '173', '280', 'cat', '35', '142', '12', '249'],
#  ['cat024.jpg', '406', '612', 'cat', '78', '301', '96', '557'],
#  ['cat025.jpg', '500', '337', 'cat', '52', '440', '72', '275'],
#  ['cat026.jpg', '3774', '5853', 'cat', '843', '2599', '1426', '4532'],
#  ['cat027.jpg', '4000', '6000', 'cat', '1156', '3674', '431', '5844'],
#  ['cat028.jpg', '4000', '6000', 'cat', '1218', '2649', '2369', '4237'],
#  ['cat029.jpg', '3744', '5616', 'cat', '330', '2813', '560', '4154'],
#  ['cat030.jpg', '4288', '2848', 'cat', '1141', '4286', '202', '2845'],
#  ['cat031.jpg', '2988', '5312', 'cat', '516', '2294', '2239', '4416'],
#  ['cat032.jpg', '8192', '8192', 'cat', '2441', '5659', '2978', '8160'],
#  ['cat033.jpg', '2380', '3583', 'cat', '463', '2247', '518', '3471'],
#  ['cat034.jpg', '3648', '5472', 'cat', '18', '3648', '59', '4588'],
#  ['cat035.jpg', '3456', '5184', 'cat', '855', '3105', '1619', '4797'],
#  ['cat036.jpg', '3875', '2640', 'cat', '1487', '3510', '547', '2511'],
#  ['cat037.jpg', '6000', '4000', 'cat', '66', '5608', '1', '3291'],
#  ['cat038.jpg', '4617', '2720', 'cat', '2023', '3586', '860', '2360'],
#  ['cat039.jpg', '6000', '4000', 'cat', '8', '4454', '216', '3687'],
#  ['cat040.jpg', '5184', '3456', 'cat', '2170', '4166', '502', '3454'],
#  ['cat041.jpg', '5184', '3456', 'cat', '1995', '3125', '765', '3061'],
#  ['cat042.jpg', '5184', '3456', 'cat', '3', '4003', '383', '3456'],
#  ['cat043.jpg', '5059', '3373', 'cat', '1858', '4372', '850', '2572'],
#  ['cat044.jpg', '5734', '3823', 'cat', '663', '5734', '47', '3319'],
#  ['cat045.jpg', '4000', '6000', 'cat', '987', '3443', '500', '5787'],
#  ['cat046.jpg', '2048', '1365', 'cat', '405', '1835', '46', '1301'],
#  ['cat047.jpg', '3855', '2500', 'cat', '514', '3161', '404', '1746'],
#  ['cat048.jpg', '5461', '8192', 'cat', '1311', '3993', '1469', '8192'],
#  ['cat049.jpg', '4272', '2848', 'cat', '1693', '2954', '290', '2618'],
#  ['cat050.jpg', '1862', '2804', 'cat', '224', '1862', '369', '2802'],
#  ['cat051.jpg', '1280', '1920', 'cat', '680', '1278', '864', '1714'],
#  ['cat052.jpg', '5616', '3744', 'cat', '984', '3200', '680', '3152'],
#  ['cat053.jpg', '7952', '5304', 'cat', '2737', '6765', '835', '4957'],
#  ['cat054.jpg', '3744', '5616', 'cat', '407', '3107', '1425', '4160'],
#  ['cat055.jpg', '5184', '3456', 'cat', '729', '2962', '465', '3072'],
#  ['cat056.jpg', '4000', '6016', 'cat', '943', '4000', '1377', '5639'],
#  ['cat057.jpg', '3072', '4026', 'cat', '422', '2522', '256', '3983'],
#  ['cat058.jpg', '3072', '4608', 'cat', '451', '2641', '679', '4608'],
#  ['cat059.jpg', '3606', '5409', 'cat', '1244', '2626', '998', '4598'],
#  ['cat060.jpg', '6000', '4000', 'cat', '2816', '5412', '820', '3183'],
#  ['cat061.jpg', '4000', '6000', 'cat', '649', '3518', '919', '5975'],
#  ['cat062.jpg', '6000', '4000', 'cat', '1483', '4837', '16', '3462'],
#  ['cat063.jpg', '2048', '3072', 'cat', '507', '1385', '1038', '2261'],
#  ['cat064.jpg', '4000', '6000', 'cat', '749', '3518', '494', '5994'],
#  ['cat065.jpg', '5200', '3466', 'cat', '918', '2878', '185', '3388'],
#  ['cat066.jpg', '5148', '3432', 'cat', '2288', '4478', '766', '3270'],
#  ['cat067.jpg', '3840', '5760', 'cat', '1507', '3407', '1930', '5392'],
#  ['cat068.jpg', '1771', '2657', 'cat', '674', '1627', '661', '2505'],
#  ['cat069.jpg', '3328', '4160', 'cat', '494', '2563', '415', '4160'],
#  ['cat070.jpg', '1200', '1200', 'cat', '12', '902', '382', '882'],
#  ['cat070.jpg', '1200', '1200', 'cat', '949', '1196', '204', '949'],
#  ['cat071.jpg', '4000', '6000', 'cat', '737', '4000', '437', '6000'],
#  ['cat072.jpg', '6000', '4000', 'cat', '400', '4783', '212', '3966'],
#  ['cat073.jpg', '3024', '4032', 'cat', '3', '2376', '633', '4032'],
#  ['cat074.jpg', '3634', '2422', 'cat', '775', '2996', '64', '1864'],
#  ['cat075.jpg', '640', '443', 'cat', '640', '640', '443', '443'],
#  ['cat075.jpg', '640', '443', 'cat', '55', '634', '23', '433'],
#  ['cat076.jpg', '480', '480', 'cat', '1', '477', '108', '437'],
#  ['cat077.jpg', '2119', '1414', 'cat', '581', '1445', '161', '1414'],
#  ['cat078.jpg', '1071', '1600', 'cat', '20', '843', '183', '1517'],
#  ['cat079.jpg', '900', '750', 'cat', '262', '849', '2', '648'],
#  ['cat080.jpg', '612', '408', 'cat', '193', '532', '38', '388'],
#  ['cat081.jpg', '1400', '1400', 'cat', '30', '428', '10', '442'],
#  ['cat081.jpg', '1400', '1400', 'cat', '483', '918', '13', '461'],
#  ['cat081.jpg', '1400', '1400', 'cat', '963', '1400', '19', '465'],
#  ['cat081.jpg', '1400', '1400', 'cat', '28', '461', '470', '933'],
#  ['cat081.jpg', '1400', '1400', 'cat', '501', '896', '510', '930'],
#  ['cat081.jpg', '1400', '1400', 'cat', '956', '1373', '467', '930'],
#  ['cat081.jpg', '1400', '1400', 'cat', '41', '460', '945', '1400'],
#  ['cat081.jpg', '1400', '1400', 'cat', '524', '908', '958', '1400'],
#  ['cat081.jpg', '1400', '1400', 'cat', '1035', '1398', '946', '1393'],
#  ['cat082.jpg', '1440', '754', 'cat', '1', '1230', '85', '675'],
#  ['cat083.jpg', '960', '540', 'cat', '244', '713', '213', '540'],
#  ['cat084.jpg', '1500', '1000', 'cat', '326', '1173', '11', '981'],
#  ['cat085.jpg', '4617', '2720', 'cat', '2029', '3562', '863', '2363'],
#  ['cat086.jpg', '1200', '1200', 'cat', '382', '1200', '55', '1196'],
#  ['cat087.jpg', '270', '187', 'cat', '1', '164', '1', '112'],
#  ['cat088.jpg', '2000', '850', 'cat', '126', '1658', '2', '837'],
#  ['cat089.jpg', '5184', '3456', 'cat', '2025', '3147', '865', '3135'],
#  ['cat090.jpg', '1200', '627', 'cat', '85', '287', '203', '437'],
#  ['cat090.jpg', '1200', '627', 'cat', '287', '437', '186', '530'],
#  ['cat090.jpg', '1200', '627', 'cat', '392', '642', '9', '589'],
#  ['cat090.jpg', '1200', '627', 'cat', '625', '877', '152', '585'],
#  ['cat090.jpg', '1200', '627', 'cat', '826', '1117', '264', '582'],
#  ['cat091.jpg', '2560', '1999', 'cat', '1', '2288', '1', '1920'],
#  ['cat092.jpg', '1050', '549', 'cat', '38', '191', '11', '248'],
#  ['cat092.jpg', '1050', '549', 'cat', '2', '134', '265', '525'],
#  ['cat092.jpg', '1050', '549', 'cat', '181', '323', '161', '371'],
#  ['cat092.jpg', '1050', '549', 'cat', '163', '359', '353', '544'],
#  ['cat092.jpg', '1050', '549', 'cat', '253', '419', '18', '162'],
#  ['cat092.jpg', '1050', '549', 'cat', '490', '651', '243', '430'],
#  ['cat092.jpg', '1050', '549', 'cat', '789', '977', '152', '459'],
#  ['cat092.jpg', '1050', '549', 'cat', '393', '521', '67', '240'],
#  ['cat092.jpg', '1050', '549', 'cat', '264', '402', '124', '265'],
#  ['cat092.jpg', '1050', '549', 'cat', '474', '655', '67', '254'],
#  ['cat092.jpg', '1050', '549', 'cat', '714', '882', '59', '169'],
#  ['cat092.jpg', '1050', '549', 'cat', '611', '753', '64', '241'],
#  ['cat092.jpg', '1050', '549', 'cat', '886', '1050', '53', '213'],
#  ['cat092.jpg', '1050', '549', 'cat', '493', '659', '6', '114'],
#  ['cat092.jpg', '1050', '549', 'cat', '322', '477', '269', '449'],
#  ['cat092.jpg', '1050', '549', 'cat', '649', '806', '339', '506'],
#  ['cat092.jpg', '1050', '549', 'cat', '710', '798', '153', '362'],
#  ['cat093.jpg', '1802', '1200', 'cat', '1117', '1638', '156', '1071'],
#  ['cat093.jpg', '1802', '1200', 'cat', '209', '1110', '149', '1200'],
#  ['cat094.jpg', '1200', '720', 'cat', '216', '970', '121', '719'],
#  ['cat095.jpg', '1080', '720', 'cat', '332', '983', '42', '689'],
#  ['cat096.jpg', '1866', '2965', 'cat', '167', '757', '1498', '2029'],
#  ['cat096.jpg', '1866', '2965', 'cat', '823', '1788', '1689', '2570'],
#  ['cat097.jpg', '1440', '560', 'cat', '1', '1081', '23', '535'],
#  ['cat098.jpg', '825', '549', 'cat', '290', '606', '103', '408'],
#  ['cat099.jpg', '1862', '2804', 'cat', '221', '1862', '366', '2804'],
#  ['cat100.jpg', '615', '769', 'cat', '158', '582', '98', '752'],
#  ['dog001.jpeg', '275', '183', 'dog', '85', '259', '36', '167'],
#  ['dog002.jpeg', '275', '183', 'dog', '32', '234', '18', '154'],
#  ['dog003.jpeg', '275', '183', 'dog', '34', '275', '11', '135'],
#  ['dog004.jpeg', '275', '183', 'dog', '41', '236', '11', '155'],
#  ['dog005.jpeg', '300', '168', 'dog', '83', '300', '1', '168'],
#  ['dog006.jpeg', '238', '212', 'dog', '13', '221', '23', '205'],
#  ['dog007.jpeg', '239', '211', 'dog', '43', '223', '33', '177'],
#  ['dog008.jpeg', '163', '308', 'dog', '19', '127', '30', '283'],
#  ['dog009.jpeg', '183', '275', 'dog', '1', '169', '1', '275'],
#  ['dog010.jpeg', '168', '300', 'dog', '63', '113', '75', '231'],
#  ['dog011.jpeg', '194', '259', 'dog', '56', '157', '39', '184'],
#  ['dog012.jpeg', '283', '178', 'dog', '91', '195', '1', '178'],
#  ['dog013.jpeg', '270', '187', 'dog', '13', '185', '27', '187'],
#  ['dog014.jpg', '2828', '4242', 'dog', '91', '2805', '675', '4242'],
#  ['dog015.jpg', '5472', '3648', 'dog', '2032', '5035', '612', '3648'],
#  ['dog016.jpg', '3888', '2592', 'dog', '1008', '3301', '293', '2525'],
#  ['dog017.jpg', '4000', '6000', 'dog', '1418', '2762', '2344', '4787'],
#  ['dog018.jpg', '3190', '4128', 'dog', '133', '2977', '173', '3821'],
#  ['dog019.jpg', '3263', '4902', 'dog', '1247', '2053', '2397', '4476'],
#  ['dog020.jpg', '3792', '4740', 'dog', '1151', '2636', '950', '4630'],
#  ['dog021.jpg', '4000', '6000', 'dog', '631', '3781', '1106', '6000'],
#  ['dog022.jpg', '3840', '5760', 'dog', '1351', '3788', '1211', '5255'],
#  ['dog023.jpg', '5461', '8192', 'dog', '784', '4430', '996', '7832'],
#  ['dog024.jpg', '3024', '4032', 'dog', '690', '2176', '1420', '3846'],
#  ['dog025.jpg', '6000', '4000', 'dog', '1', '3616', '358', '4000'],
#  ['dog026.jpg', '4160', '6240', 'dog', '1', '3933', '1980', '6240'],
#  ['dog027.jpg', '6000', '4000', 'dog', '691', '4262', '675', '4000'],
#  ['dog028.jpg', '2000', '1496', 'dog', '338', '854', '162', '1309'],
#  ['dog029.jpg', '3456', '5184', 'dog', '294', '3339', '186', '5184'],
#  ['dog030.jpg', '3209', '5702', 'dog', '1161', '2167', '1763', '3926'],
#  ['dog031.jpg', '2939', '3919', 'dog', '674', '2939', '1051', '3919'],
#  ['dog032.jpg', '5472', '3648', 'dog', '1139', '5451', '362', '3470'],
#  ['dog033.jpg', '2309', '3464', 'dog', '306', '2306', '1210', '2839'],
#  ['dog034.jpg', '2799', '2000', 'dog', '780', '1724', '166', '1845'],
#  ['dog035.jpg', '5278', '3158', 'dog', '1549', '3125', '127', '2903'],
#  ['dog036.jpg', '3531', '4569', 'dog', '1175', '3179', '1670', '4232'],
#  ['dog037.jpg', '3264', '4928', 'dog', '147', '1737', '253', '3326'],
#  ['dog038.jpg', '5184', '3456', 'dog', '2303', '4336', '365', '3269'],
#  ['dog039.jpg', '4000', '6000', 'dog', '662', '2649', '1469', '5050'],
#  ['dog040.jpg', '3761', '2518', 'dog', '1190', '2501', '398', '2345'],
#  ['dog041.jpg', '3008', '2000', 'dog', '568', '2498', '243', '2000'],
#  ['dog042.jpg', '5876', '3521', 'dog', '1507', '4622', '606', '2644'],
#  ['dog043.jpg', '6000', '4000', 'dog', '1212', '5016', '875', '3400'],
#  ['dog044.jpg', '1898', '1920', 'dog', '133', '1521', '190', '1814'],
#  ['dog045.jpg', '3024', '3024', 'dog', '715', '2253', '701', '2769'],
#  ['dog046.jpg', '3008', '2000', 'dog', '579', '2645', '343', '1947'],
#  ['dog047.jpg', '3648', '5472', 'dog', '1094', '2318', '1835', '4523'],
#  ['dog048.jpg', '3456', '5184', 'dog', '933', '3272', '402', '4836'],
#  ['dog049.jpg', '2560', '1920', 'dog', '1200', '2376', '424', '1920'],
#  ['dog050.jpg', '3024', '4032', 'dog', '1', '2598', '690', '3881'],
#  ['dog051.jpg', '4480', '6720', 'dog', '1311', '4480', '2853', '6053'],
#  ['dog052.jpg', '5184', '3456', 'dog', '1310', '5162', '20', '3456'],
#  ['dog053.jpg', '5623', '3749', 'dog', '1719', '4479', '814', '3749'],
#  ['dog054.jpg', '4912', '2760', 'dog', '2091', '4681', '73', '2760'],
#  ['dog055.jpg', '6288', '4912', 'dog', '517', '4775', '824', '4771'],
#  ['dog056.jpg', '1952', '1375', 'dog', '942', '1610', '100', '1250'],
#  ['dog057.jpg', '3258', '4216', 'dog', '279', '2733', '385', '4216'],
#  ['dog058.jpg', '2828', '4242', 'dog', '182', '2532', '1407', '3193'],
#  ['dog059.jpg', '3072', '4608', 'dog', '526', '2801', '1844', '4064'],
#  ['dog060.jpg', '3867', '5800', 'dog', '1083', '3027', '1875', '5525'],
#  ['dog061.jpg', '4640', '6960', 'dog', '5', '3043', '1756', '6287'],
#  ['dog061.jpg', '4640', '6960', 'dog', '2320', '3781', '2410', '5502'],
#  ['dog062.jpg', '4000', '2723', 'dog', '854', '1951', '555', '2561'],
#  ['dog063.jpg', '2738', '1825', 'dog', '1134', '2286', '606', '1731'],
#  ['dog064.jpg', '4032', '6048', 'dog', '968', '3962', '1996', '5011'],
#  ['dog065.jpg', '5480', '3653', 'dog', '1463', '4109', '199', '3545'],
#  ['dog066.jpg', '3275', '4238', 'dog', '1', '3232', '678', '4238'],
#  ['dog067.jpg', '3456', '5184', 'dog', '800', '3011', '647', '4819'],
#  ['dog068.jpg', '4928', '3264', 'dog', '522', '2808', '114', '3035'],
#  ['dog069.jpg', '3264', '2448', 'dog', '631', '2585', '188', '2321'],
#  ['dog070.jpg', '5472', '3648', 'dog', '285', '3682', '639', '3539'],
#  ['dog071.jpg', '5051', '3372', 'dog', '4', '4279', '229', '3372'],
#  ['dog072.jpg', '4000', '6000', 'dog', '812', '3868', '1650', '5975'],
#  ['dog073.jpg', '2367', '3441', 'dog', '258', '2004', '359', '3006'],
#  ['dog074.jpg', '3024', '4032', 'dog', '516', '3024', '677', '4032'],
#  ['dog075.jpg', '4297', '5371', 'dog', '806', '3153', '1091', '4938'],
#  ['dog076.jpg', '2680', '3976', 'dog', '260', '2680', '375', '3976'],
#  ['dog077.jpg', '5184', '3456', 'dog', '1270', '4492', '176', '3456'],
#  ['dog078.jpg', '3560', '5340', 'dog', '963', '2602', '2264', '3792'],
#  ['dog079.jpg', '4288', '2848', 'dog', '644', '4288', '248', '2848'],
#  ['dog080.jpg', '5472', '7296', 'dog', '1282', '5367', '1194', '7296'],
#  ['dog081.jpg', '3024', '4032', 'dog', '420', '2816', '390', '4032'],
#  ['dog082.jpg', '3744', '5616', 'dog', '413', '3336', '1237', '5490'],
#  ['dog083.jpg', '4881', '6101', 'dog', '1', '3733', '1110', '6030'],
#  ['dog084.jpg', '5616', '3744', 'dog', '484', '5180', '516', '2944'],
#  ['dog085.jpg', '3365', '4355', 'dog', '455', '2859', '318', '4150'],
#  ['dog086.jpg', '4859', '3090', 'dog', '320', '3900', '363', '3038'],
#  ['dog087.jpg', '2444', '1648', 'dog', '1135', '1642', '250', '1382'],
#  ['dog088.jpg', '5184', '3456', 'dog', '1573', '3670', '717', '3135'],
#  ['dog089.jpg', '4000', '5176', 'dog', '244', '3305', '1160', '4804'],
#  ['dog090.jpg', '4608', '3072', 'dog', '445', '3629', '551', '3072'],
#  ['dog091.jpg', '6016', '4000', 'dog', '1370', '5378', '41', '4000'],
#  ['dog092.jpg', '5184', '3456', 'dog', '1895', '3910', '558', '3328'],
#  ['dog093.jpg', '5184', '3456', 'dog', '562', '2821', '246', '3450'],
#  ['dog094.jpg', '3456', '5184', 'dog', '744', '2994', '219', '5184'],
#  ['dog095.jpg', '3456', '5184', 'dog', '855', '2617', '2108', '5158'],
#  ['dog096.jpg', '3872', '2592', 'dog', '524', '3872', '47', '2287'],
#  ['dog097.jpg', '5014', '7358', 'dog', '576', '3945', '1532', '6809'],
#  ['dog098.jpg', '3589', '6241', 'dog', '874', '2847', '2187', '4260'],
#  ['dog099.jpg', '2316', '3744', 'dog', '366', '2316', '500', '3744'],
#  ['dog100.jpg', '2878', '1871', 'dog', '1407', '2819', '153', '1800']]

# %%
df = pd.DataFrame(data, columns = ['filename', 'width', 'height', 'name', 'xmin', 'xmax', 'ymin', 'ymax'])

# %%
df.head()
# Out:
#      filename width height name xmin  xmax ymin  ymax
# 0  cat001.jpg  1000    688  cat  124   834  156   685
# 1  cat002.jpg  1400    700  cat  390  1219   48   697
# 2  cat003.jpg  1080   1080  cat  140   685    1  1072
# 3  cat004.jpg   530    640  cat   64   470   57   640
# 4  cat004.jpg   530    640  cat   64   469   58   639

# %%
df.shape
# Out:
# (234, 8)

# %%
df['name'].value_counts()
# Out:
# name
# cat    133
# dog    101
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  234 non-null    object
#  1   width     234 non-null    object
#  2   height    234 non-null    object
#  3   name      234 non-null    object
#  4   xmin      234 non-null    object
#  5   xmax      234 non-null    object
#  6   ymin      234 non-null    object
#  7   ymax      234 non-null    object
# dtypes: object(8)
# memory usage: 14.8+ KB

# %%
cols = ['width', 'height', 'xmin', 'xmax', 'ymin', 'ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  234 non-null    object
#  1   width     234 non-null    int32
#  2   height    234 non-null    int32
#  3   name      234 non-null    object
#  4   xmin      234 non-null    int32
#  5   xmax      234 non-null    int32
#  6   ymin      234 non-null    int32
#  7   ymax      234 non-null    int32
# dtypes: int32(6), object(2)
# memory usage: 9.3+ KB

# %%
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']
df['w'] = (df['xmax']-df['xmin'])/df['width']
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#      filename  width  height name  xmin  xmax  ymin  ymax  center_x  center_y  \
# 0  cat001.jpg   1000     688  cat   124   834   156   685  0.479000  0.611192
# 1  cat002.jpg   1400     700  cat   390  1219    48   697  0.574643  0.532143
# 2  cat003.jpg   1080    1080  cat   140   685     1  1072  0.381944  0.496759
# 3  cat004.jpg    530     640  cat    64   470    57   640  0.503774  0.544531
# 4  cat004.jpg    530     640  cat    64   469    58   639  0.502830  0.544531
#
#           w         h
# 0  0.710000  0.768895
# 1  0.592143  0.927143
# 2  0.504630  0.991667
# 3  0.766038  0.910937
# 4  0.764151  0.907813

# %%
images = df['filename'].unique()

# %%
len(images)
# Out:
# 200

# %%
img_df = pd.DataFrame(images,columns=['filename'])
img_train = tuple(img_df.sample(frac=0.7)['filename'])

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename']) #testowych 30%

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#      filename  width  height name  xmin  xmax  ymin  ymax  center_x  center_y  \
# 0  cat001.jpg   1000     688  cat   124   834   156   685  0.479000  0.611192
# 1  cat002.jpg   1400     700  cat   390  1219    48   697  0.574643  0.532143
# 3  cat004.jpg    530     640  cat    64   470    57   640  0.503774  0.544531
# 4  cat004.jpg    530     640  cat    64   469    58   639  0.502830  0.544531
# 5  cat005.jpg    210     210  cat    13   188     8   198  0.478571  0.490476
#
#           w         h
# 0  0.710000  0.768895
# 1  0.592143  0.927143
# 3  0.766038  0.910937
# 4  0.764151  0.907813
# 5  0.833333  0.904762

# %%
def label_encoding(x):
    labels = {'cat':0, 'dog':1}
    return labels[x]

# %%
train_df['id'] = train_df['name'].apply(label_encoding)
test_df['id'] = test_df['name'].apply(label_encoding)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_12732\1789319663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['id'] = train_df['name'].apply(label_encoding)
# C:\Users\acer\AppData\Local\Temp\ipykernel_12732\1789319663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['id'] = test_df['name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#        filename  width  height name  xmin  xmax  ymin  ymax  center_x  \
# 0    cat001.jpg   1000     688  cat   124   834   156   685  0.479000
# 1    cat002.jpg   1400     700  cat   390  1219    48   697  0.574643
# 3    cat004.jpg    530     640  cat    64   470    57   640  0.503774
# 4    cat004.jpg    530     640  cat    64   469    58   639  0.502830
# 5    cat005.jpg    210     210  cat    13   188     8   198  0.478571
# 6    cat006.jpg   1400     845  cat   422  1259    13   840  0.600357
# 9    cat009.jpg    700     467  cat   207   562    33   381  0.549286
# 10   cat010.jpg   1471     980  cat    44  1428   143   797  0.500340
# 11   cat011.jpg   6000    4000  cat   354  4754   262  3975  0.425667
# 12  cat012.jpeg    194     260  cat    45   183    27   239  0.587629
#
#     center_y         w         h  id
# 0   0.611192  0.710000  0.768895   0
# 1   0.532143  0.592143  0.927143   0
# 3   0.544531  0.766038  0.910937   0
# 4   0.544531  0.764151  0.907813   0
# 5   0.490476  0.833333  0.904762   0
# 6   0.504734  0.597857  0.978698   0
# 9   0.443255  0.507143  0.745182   0
# 10  0.479592  0.940857  0.667347   0
# 11  0.529625  0.733333  0.928250   0
# 12  0.511538  0.711340  0.815385   0

# %%
import os
from shutil import move

# %%
train_folder = 'data_images/train/'
test_folder = 'data_images/test'

os.mkdir(train_folder)
os.mkdir(test_folder)

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
groupby_obj_train.get_group('cat001.jpg')
# Out:
#      filename  id  center_x  center_y     w         h
# 0  cat001.jpg   0     0.479  0.611192  0.71  0.768895

# %%
def save_data(filename, folder_path, group_obj):
    src = os.path.join('data_images',filename)
    dst = os.path.join(folder_path,filename)
    move(src,dst)
    
    text_filename = os.path.join(folder_path, os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
groupby_obj_train.groups.keys()
# Out:
# dict_keys(['cat001.jpg', 'cat002.jpg', 'cat004.jpg', 'cat005.jpg', 'cat006.jpg', 'cat009.jpg', 'cat010.jpg', 'cat011.jpg', 'cat012.jpeg', 'cat014.jpeg', 'cat015.jpeg', 'cat019.jpeg', 'cat020.jpeg', 'cat021.jpeg', 'cat023.jpeg', 'cat024.jpg', 'cat025.jpg', 'cat027.jpg', 'cat028.jpg', 'cat033.jpg', 'cat034.jpg', 'cat035.jpg', 'cat036.jpg', 'cat037.jpg', 'cat038.jpg', 'cat039.jpg', 'cat042.jpg', 'cat043.jpg', 'cat044.jpg', 'cat045.jpg', 'cat046.jpg', 'cat047.jpg', 'cat048.jpg', 'cat049.jpg', 'cat050.jpg', 'cat051.jpg', 'cat052.jpg', 'cat053.jpg', 'cat054.jpg', 'cat055.jpg', 'cat056.jpg', 'cat057.jpg', 'cat058.jpg', 'cat059.jpg', 'cat060.jpg', 'cat061.jpg', 'cat062.jpg', 'cat064.jpg', 'cat065.jpg', 'cat069.jpg', 'cat071.jpg', 'cat072.jpg', 'cat074.jpg', 'cat075.jpg', 'cat077.jpg', 'cat078.jpg', 'cat079.jpg', 'cat080.jpg', 'cat081.jpg', 'cat082.jpg', 'cat083.jpg', 'cat084.jpg', 'cat085.jpg', 'cat086.jpg', 'cat087.jpg', 'cat088.jpg', 'cat089.jpg', 'cat090.jpg', 'cat091.jpg', 'cat092.jpg', 'cat093.jpg', 'cat097.jpg', 'cat099.jpg', 'cat100.jpg', 'dog001.jpeg', 'dog003.jpeg', 'dog006.jpeg', 'dog008.jpeg', 'dog009.jpeg', 'dog011.jpeg', 'dog012.jpeg', 'dog013.jpeg', 'dog017.jpg', 'dog018.jpg', 'dog020.jpg', 'dog021.jpg', 'dog023.jpg', 'dog025.jpg', 'dog029.jpg', 'dog030.jpg', 'dog033.jpg', 'dog034.jpg', 'dog035.jpg', 'dog036.jpg', 'dog037.jpg', 'dog038.jpg', 'dog040.jpg', 'dog041.jpg', 'dog042.jpg', 'dog043.jpg', 'dog044.jpg', 'dog046.jpg', 'dog048.jpg', 'dog049.jpg', 'dog050.jpg', 'dog051.jpg', 'dog053.jpg', 'dog055.jpg', 'dog056.jpg', 'dog057.jpg', 'dog058.jpg', 'dog059.jpg', 'dog061.jpg', 'dog062.jpg', 'dog063.jpg', 'dog065.jpg', 'dog066.jpg', 'dog068.jpg', 'dog070.jpg', 'dog071.jpg', 'dog073.jpg', 'dog075.jpg', 'dog077.jpg', 'dog079.jpg', 'dog081.jpg', 'dog082.jpg', 'dog085.jpg', 'dog086.jpg', 'dog087.jpg', 'dog088.jpg', 'dog089.jpg', 'dog090.jpg', 'dog091.jpg', 'dog093.jpg', 'dog095.jpg', 'dog096.jpg', 'dog097.jpg', 'dog098.jpg', 'dog099.jpg', 'dog100.jpg'])
